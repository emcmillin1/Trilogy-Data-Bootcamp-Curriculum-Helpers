# %% [markdown]
# # Demo: tweepy

# %%
import os, sys, json 
import tweepy
import pandas as pd
import pprint
from collections import defaultdict

# %%
# read in enviroment variables for authentication
TWITTER_KEY = os.environ["TWITTER_KEY"]
TWITTER_SECRET = os.environ["TWITTER_SECRET"]
TWITTER_ACCESS_TOKEN = os.environ["TWITTER_ACCESS_TOKEN"]
TWITTER_ACCESS_SECRET = os.environ["TWITTER_ACCESS_SECRET"]

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(TWITTER_KEY, TWITTER_SECRET)
auth.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_SECRET)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# read user timeline
user = '@POTUS'
response = api.user_timeline(user)

# %%
# looking at first response entry 
r = response[0]

# %%
# pretty print 
pprint.pprint(r)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Aug 30 16:58:27 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 822215673812119553,
#                                  'id_str': '822215673812119553',
#                                  'indices': [3, 14],
#                                  'name': 'The White House',
#                                  'screen_name': 'WhiteHouse'},
#                                 {'id': 25073877,
#                                  'id_str': '25073877',
#                                  'indices': [95, 111],
#                                  'name': 'Donald J. Trump',
#                                  'screen_name': 'realDonaldTrump'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1035210149059874818,
#  'id_str': '1035210149059874818',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 878,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Thu Aug 30 16:58:01 +0000 2018',
#                       'entities': {'hashtags': [],
#                                    'symbols': [],
#                                    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                              'expanded_url': 'https://twitter.com/i/web/status/1035210041039745025',
#                                              'indices': [117, 140],
#                                              'url': 'https://t.co/baDo0ci7BW'}],
#                                    'user_mentions': [{'id': 25073877,
#                                                       'id_str': '25073877',
#                                                       'indices': [79, 95],
#                                                       'name': 'Donald J. Trump',
#                                                       'screen_name': 'realDonaldTrump'}]},
#                       'favorite_count': 3327,
#                       'favorited': False,
#                       'geo': None,
#                       'id': 1035210041039745025,
#                       'id_str': '1035210041039745025',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'retweet_count': 878,
#                       'retweeted': False,
#                       'source': '<a href="https://www.whitehouse.gov/" '
#                                 'rel="nofollow">WH Digital</a>',
#                       'text': 'Economic gains exceeded expectations in the '
#                               'first full quarter since President '
#                               "@realDonaldTrump's Tax Cuts and Jobs… "
#                               'https://t.co/baDo0ci7BW',
#                       'truncated': True,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Thu Jan 19 22:54:27 +0000 2017',
#                                'default_profile': True,
#                                'default_profile_image': False,
#                                'description': 'Welcome to @WhiteHouse! Follow '
#                                               'for the latest from President '
#                                               '@realDonaldTrump and his '
#                                               'Administration. Tweets may be '
#                                               'archived: '
#                                               'https://t.co/IURuMIrzxb',
#                                'entities': {'description': {'urls': [{'display_url': 'whitehouse.gov/privacy',
#                                                                       'expanded_url': 'http://whitehouse.gov/privacy',
#                                                                       'indices': [126,
#                                                                                   149],
#                                                                       'url': 'https://t.co/IURuMIrzxb'}]},
#                                             'url': {'urls': [{'display_url': 'WhiteHouse.gov',
#                                                               'expanded_url': 'http://www.WhiteHouse.gov',
#                                                               'indices': [0,
#                                                                           23],
#                                                               'url': 'https://t.co/wyOVgSLgBV'}]}},
#                                'favourites_count': 9,
#                                'follow_request_sent': False,
#                                'followers_count': 17207301,
#                                'following': False,
#                                'friends_count': 12,
#                                'geo_enabled': True,
#                                'has_extended_profile': False,
#                                'id': 822215673812119553,
#                                'id_str': '822215673812119553',
#                                'is_translation_enabled': False,
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 8444,
#                                'location': 'Washington, D.C.',
#                                'name': 'The White House',
#                                'notifications': False,
#                                'profile_background_color': 'F5F8FA',
#                                'profile_background_image_url': None,
#                                'profile_background_image_url_https': None,
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/822215673812119553/1508763959',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/822251886988267520/28GpoRsy_normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822251886988267520/28GpoRsy_normal.jpg',
#                                'profile_link_color': '1DA1F2',
#                                'profile_sidebar_border_color': 'C0DEED',
#                                'profile_sidebar_fill_color': 'DDEEF6',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'WhiteHouse',
#                                'statuses_count': 5296,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': 'https://t.co/wyOVgSLgBV',
#                                'utc_offset': None,
#                                'verified': True}},
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'text': 'RT @WhiteHouse: Economic gains exceeded expectations in the first '
#          "full quarter since President @realDonaldTrump's Tax Cuts and Jobs "
#          'Act too…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Jan 19 22:54:28 +0000 2017',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': '45th President of the United States of America, '
#                          '@realDonaldTrump. Tweets archived: '
#                          'https://t.co/eVVzoBb3Zr',
#           'entities': {'description': {'urls': [{'display_url': 'wh.gov/privacy',
#                                                  'expanded_url': 'http://wh.gov/privacy',
#                                                  'indices': [83, 106],
#                                                  'url': 'https://t.co/eVVzoBb3Zr'}]},
#                        'url': {'urls': [{'display_url': 'WhiteHouse.gov',
#                                          'expanded_url': 'http://WhiteHouse.gov',
#                                          'indices': [0, 23],
#                                          'url': 'https://t.co/IxLjEB2zlE'}]}},
#           'favourites_count': 104,
#           'follow_request_sent': False,
#           'followers_count': 23926448,
#           'following': False,
#           'friends_count': 39,
#           'geo_enabled': True,
#           'has_extended_profile': False,
#           'id': 822215679726100480,
#           'id_str': '822215679726100480',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 20176,
#           'location': 'Washington, D.C.',
#           'name': 'President Trump',
#           'notifications': False,
#           'profile_background_color': 'F5F8FA',
#           'profile_background_image_url': None,
#           'profile_background_image_url_https': None,
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/822215679726100480/1507040566',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/859982100904148992/hv5soju7_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/859982100904148992/hv5soju7_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'POTUS',
#           'statuses_count': 3821,
#           'time_zone': None,
#           'translator_type': 'regular',
#           'url': 'https://t.co/IxLjEB2zlE',
#           'utc_offset': None,
#           'verified': True}}

# %%
# checking logic on first entry 
creation = r['created_at']
text = r['text']
print(creation, text)
# Out:
# Thu Aug 30 16:58:27 +0000 2018 RT @WhiteHouse: Economic gains exceeded expectations in the first full quarter since President @realDonaldTrump's Tax Cuts and Jobs Act too…

# %%
# create outer list to hold values 
df_stage = []
# iterate through json response 
for r in response:
    # grab values
    creation = r['created_at']
    text = r['text']
    # create a list of these values 
    lst = [creation, text]
    # append inner list to outer list 
    df_stage.append(lst)
    
# create column headers
columns = ['created_at','text']
# init dataframe
df = pd.DataFrame(df_stage, columns=columns)

# %%
# looking at first text entry
text = df.loc[0, 'text']
text
# Out:
# "RT @WhiteHouse: Economic gains exceeded expectations in the first full quarter since President @realDonaldTrump's Tax Cuts and Jobs Act too…"

# %%
# init counter object
d = defaultdict(int)

# %%
# define count function and check against one example 
def count_words(text):
    # break string into list of words
    words = text.split(' ')
    print(words)
    # iterate through words
    for word in words:
        # increment word counter
        d[word]+=1
        
# test run
count_words(text)
# Out:
# ['RT', '@WhiteHouse:', 'Economic', 'gains', 'exceeded', 'expectations', 'in', 'the', 'first', 'full', 'quarter', 'since', 'President', "@realDonaldTrump's", 'Tax', 'Cuts', 'and', 'Jobs', 'Act', 'too…']

# %%
# run function against all text values
df.text.apply(count_words)
# Out:
# ['RT', '@WhiteHouse:', 'Economic', 'gains', 'exceeded', 'expectations', 'in', 'the', 'first', 'full', 'quarter', 'since', 'President', "@realDonaldTrump's", 'Tax', 'Cuts', 'and', 'Jobs', 'Act', 'too…']
# ['RT', '@FLOTUS:', 'Congratulations', 'to', '@WhiteHouseHstry', 'on', 'a', 'successful', '#PresidentialSites', 'Summit.', 'It', 'was', 'great', 'hosting', 'you', 'at', 'the', '@WhiteHouse', 'http…']
# ['RT', '@realDonaldTrump:', 'STATEMENT', 'FROM', 'THE', 'WHITE', 'HOUSE\n\nPresident', 'Donald', 'J.', 'Trump', 'feels', 'strongly', 'that', 'North', 'Korea', 'is', 'under', 'tremendous', 'pressure…']
# ['RT', '@WhiteHouse:', 'Families', 'across', 'the', 'country', 'are', 'affected', 'by', 'substance', 'abuse,', 'and', 'President', "Trump's", 'was', 'no', 'different.', '\n\n"[My', 'brother', 'Fred]', 'h…']
# ['RT', '@realDonaldTrump:', '#StopTheBias', 'https://t.co/xqz599iQZw']
# ['RT', '@WhiteHouse:', 'New', 'report', 'just', 'in', 'from', '@CommerceGov:', 'Economic', 'growth', 'exceeded', 'original', 'estimates', 'for', 'April', 'to', 'June', '2018—the', 'first', 'full', 'qua…']
# ['RT', '@WhiteHouse:', '“We', 'are', 'a', 'political', 'monoculture', 'that’s', 'intolerant', 'of', 'different', 'views,”', 'a', 'senior', 'Facebook', 'engineer', 'wrote', 'in', 'a', 'post', 'that', '"qui…']
# ['RT', '@realDonaldTrump:', 'White', 'House', 'Counsel', 'Don', 'McGahn', 'will', 'be', 'leaving', 'his', 'position', 'in', 'the', 'fall,', 'shortly', 'after', 'the', 'confirmation', '(hopefully)', 'of…']
# ['RT', '@realDonaldTrump:', 'Add', 'the', '2026', 'World', 'Cup', 'to', 'our', 'long', 'list', 'of', 'accomplishments!']
# ['RT', '@WhiteHouse:', 'President', '@realDonaldTrump', 'is', 'excited', 'that', 'the', 'United', 'States,', 'along', 'with', 'Mexico', 'and', 'Canada,', 'will', 'be', 'hosting', 'the', '2026', '@FIFAW…']
# ['RT', '@realDonaldTrump:', 'https://t.co/H2FiSVxyOF']
# ['RT', '@WhiteHouse:', '.@RepKevinBrady', 'praises', 'the', 'new', 'U.S.–Mexico', 'Trade', 'Agreement', 'for', 'its', 'benefits', 'to', '"American', 'workers,', 'farmers,', 'and', 'local', 'busin…']
# ['RT', '@WhiteHouse:', '.@RepArrington:', '"[I]', 'am', 'confident', 'our', 'Negotiator-in-Chief', 'will', 'close', 'a', 'deal', 'that', 'benefits', 'all', 'Americans."', 'https://t.co/CYIw…']
# ['RT', '@realDonaldTrump:', '“Consumer', 'confidence', 'pops', 'in', 'August', 'to', 'highest', 'level', 'since', 'October', '2000”', 'https://t.co/1Gg5IOtbNa']
# ['RT', '@WhiteHouse:', '.@SteveScalise:', "America's", 'new', 'preliminary', 'deal', 'with', 'Mexico', '"will', 'send', 'a', 'strong', 'message', 'to', 'other', 'countries', 'around', 'the', 'world…']
# ['RT', '@VP:', 'Honored', 'to', 'join', '@POTUS', '&amp;', '@FLOTUS', 'tonight', 'at', 'the', '@WhiteHouse', 'to', 'celebrate', 'strong', 'and', 'inspiring', 'evangelical', 'leadership.', 'This', 'administ…']
# ['RT', '@FLOTUS:', 'It', 'was', 'wonderful', 'to', 'host', 'Evangelical', 'leaders', 'at', 'the', '@WhiteHouse', 'tonight.', 'https://t.co/8R4jC6VVJr']
# ['RT', '@WhiteHouse:', '“Many', 'people', 'thought', 'that', 'this', 'was', 'something', 'that', 'just', 'couldn’t', 'happen', 'because', 'of', 'all', 'of', 'the', 'different', 'factions,', 'all', 'of', 'the…']
# ['RT', '@FLOTUS:', 'I', 'had', 'the', 'honor', 'to', 'contribute', 'to', 'the', 'beautiful', '&amp;', 'historic', '@WhiteHouse', 'grounds', 'today', 'by', 'planting', 'a', 'sapling', 'from', 'the', 'Eisenhower', 'O…']
# ['RT', '@FLOTUS:', '.@POTUS', '&amp;', 'I', 'welcomed', '@UKenyatta', '&amp;', 'Mrs.', 'Kenyatta', 'to', 'the', '@WhiteHouse', 'today.', 'I', 'enjoyed', 'my', 'time', 'with', 'the', 'First', 'Lady', 'of', 'Kenya,', 'discu…']
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# Name: text, dtype: object

# %%
# check output 
d
# Out:
# defaultdict(int,
#             {'RT': 21,
#              '@WhiteHouse:': 10,
#              'Economic': 3,
#              'gains': 2,
#              'exceeded': 3,
#              'expectations': 2,
#              'in': 6,
#              'the': 19,
#              'first': 3,
#              'full': 3,
#              'quarter': 2,
#              'since': 3,
#              'President': 4,
#              "@realDonaldTrump's": 2,
#              'Tax': 2,
#              'Cuts': 2,
#              'and': 6,
#              'Jobs': 2,
#              'Act': 2,
#              'too…': 2,
#              '@FLOTUS:': 4,
#              'Congratulations': 1,
#              'to': 12,
#              '@WhiteHouseHstry': 1,
#              'on': 1,
#              'a': 7,
#              'successful': 1,
#              '#PresidentialSites': 1,
#              'Summit.': 1,
#              'It': 2,
#              'was': 4,
#              'great': 1,
#              'hosting': 2,
#              'you': 1,
#              'at': 3,
#              '@WhiteHouse': 5,
#              'http…': 1,
#              '@realDonaldTrump:': 6,
#              'STATEMENT': 1,
#              'FROM': 1,
#              'THE': 1,
#              'WHITE': 1,
#              'HOUSE\n\nPresident': 1,
#              'Donald': 1,
#              'J.': 1,
#              'Trump': 1,
#              'feels': 1,
#              'strongly': 1,
#              'that': 6,
#              'North': 1,
#              'Korea': 1,
#              'is': 2,
#              'under': 1,
#              'tremendous': 1,
#              'pressure…': 1,
#              'Families': 1,
#              'across': 1,
#              'country': 1,
#              'are': 2,
#              'affected': 1,
#              'by': 2,
#              'substance': 1,
#              'abuse,': 1,
#              "Trump's": 1,
#              'no': 1,
#              'different.': 1,
#              '\n\n"[My': 1,
#              'brother': 1,
#              'Fred]': 1,
#              'h…': 1,
#              '#StopTheBias': 1,
#              'https://t.co/xqz599iQZw': 1,
#              'New': 1,
#              'report': 1,
#              'just': 2,
#              'from': 2,
#              '@CommerceGov:': 1,
#              'growth': 1,
#              'original': 1,
#              'estimates': 1,
#              'for': 2,
#              'April': 1,
#              'June': 1,
#              '2018—the': 1,
#              'qua…': 1,
#              '“We': 1,
#              'political': 1,
#              'monoculture': 1,
#              'that’s': 1,
#              'intolerant': 1,
#              'of': 6,
#              'different': 2,
#              'views,”': 1,
#              'senior': 1,
#              'Facebook': 1,
#              'engineer': 1,
#              'wrote': 1,
#              'post': 1,
#              '"qui…': 1,
#              'White': 1,
#              'House': 1,
#              'Counsel': 1,
#              'Don': 1,
#              'McGahn': 1,
#              'will': 3,
#              'be': 2,
#              'leaving': 1,
#              'his': 1,
#              'position': 1,
#              'fall,': 1,
#              'shortly': 1,
#              'after': 1,
#              'confirmation': 1,
#              '(hopefully)': 1,
#              'of…': 1,
#              'Add': 1,
#              '2026': 2,
#              'World': 1,
#              'Cup': 1,
#              'our': 2,
#              'long': 1,
#              'list': 1,
#              'accomplishments!': 1,
#              '@realDonaldTrump': 1,
#              'excited': 1,
#              'United': 1,
#              'States,': 1,
#              'along': 1,
#              'with': 3,
#              'Mexico': 2,
#              'Canada,': 1,
#              '@FIFAW…': 1,
#              'https://t.co/H2FiSVxyOF': 1,
#              '.@RepKevinBrady': 1,
#              'praises': 1,
#              'new': 2,
#              'U.S.–Mexico': 1,
#              'Trade': 1,
#              'Agreement': 1,
#              'its': 1,
#              'benefits': 2,
#              '"American': 1,
#              'workers,': 1,
#              'farmers,': 1,
#              'local': 1,
#              'busin…': 1,
#              '.@RepArrington:': 1,
#              '"[I]': 1,
#              'am': 1,
#              'confident': 1,
#              'Negotiator-in-Chief': 1,
#              'close': 1,
#              'deal': 2,
#              'all': 3,
#              'Americans."': 1,
#              'https://t.co/CYIw…': 1,
#              '“Consumer': 1,
#              'confidence': 1,
#              'pops': 1,
#              'August': 1,
#              'highest': 1,
#              'level': 1,
#              'October': 1,
#              '2000”': 1,
#              'https://t.co/1Gg5IOtbNa': 1,
#              '.@SteveScalise:': 1,
#              "America's": 1,
#              'preliminary': 1,
#              '"will': 1,
#              'send': 1,
#              'strong': 2,
#              'message': 1,
#              'other': 1,
#              'countries': 1,
#              'around': 1,
#              'world…': 1,
#              '@VP:': 1,
#              'Honored': 1,
#              'join': 1,
#              '@POTUS': 1,
#              '&amp;': 4,
#              '@FLOTUS': 1,
#              'tonight': 1,
#              'celebrate': 1,
#              'inspiring': 1,
#              'evangelical': 1,
#              'leadership.': 1,
#              'This': 1,
#              'administ…': 1,
#              'wonderful': 1,
#              'host': 1,
#              'Evangelical': 1,
#              'leaders': 1,
#              'tonight.': 1,
#              'https://t.co/8R4jC6VVJr': 1,
#              '“Many': 1,
#              'people': 1,
#              'thought': 1,
#              'this': 1,
#              'something': 1,
#              'couldn’t': 1,
#              'happen': 1,
#              'because': 1,
#              'factions,': 1,
#              'the…': 1,
#              'I': 3,
#              'had': 1,
#              'honor': 1,
#              'contribute': 1,
#              'beautiful': 1,
#              'historic': 1,
#              'grounds': 1,
#              'today': 1,
#              'planting': 1,
#              'sapling': 1,
#              'Eisenhower': 1,
#              'O…': 1,
#              '.@POTUS': 1,
#              'welcomed': 1,
#              '@UKenyatta': 1,
#              'Mrs.': 1,
#              'Kenyatta': 1,
#              'today.': 1,
#              'enjoyed': 1,
#              'my': 1,
#              'time': 1,
#              'First': 1,
#              'Lady': 1,
#              'Kenya,': 1,
#              'discu…': 1})

# %%
# return sorted (max first) list using lambda syntax
    # lambda x: (for each value of x)
    # d[x] (look at the value of d[x])
    # then (use this as the key to return a sorted list of keys in reverse order)
srted = sorted(d, key = lambda x: d[x], reverse=True)
srted
# Out:
# ['RT',
#  'the',
#  'to',
#  '@WhiteHouse:',
#  'a',
#  'in',
#  'and',
#  '@realDonaldTrump:',
#  'that',
#  'of',
#  '@WhiteHouse',
#  'President',
#  '@FLOTUS:',
#  'was',
#  '&amp;',
#  'Economic',
#  'exceeded',
#  'first',
#  'full',
#  'since',
#  'at',
#  'will',
#  'with',
#  'all',
#  'I',
#  'gains',
#  'expectations',
#  'quarter',
#  "@realDonaldTrump's",
#  'Tax',
#  'Cuts',
#  'Jobs',
#  'Act',
#  'too…',
#  'It',
#  'hosting',
#  'is',
#  'are',
#  'by',
#  'just',
#  'from',
#  'for',
#  'different',
#  'be',
#  '2026',
#  'our',
#  'Mexico',
#  'new',
#  'benefits',
#  'deal',
#  'strong',
#  'Congratulations',
#  '@WhiteHouseHstry',
#  'on',
#  'successful',
#  '#PresidentialSites',
#  'Summit.',
#  'great',
#  'you',
#  'http…',
#  'STATEMENT',
#  'FROM',
#  'THE',
#  'WHITE',
#  'HOUSE\n\nPresident',
#  'Donald',
#  'J.',
#  'Trump',
#  'feels',
#  'strongly',
#  'North',
#  'Korea',
#  'under',
#  'tremendous',
#  'pressure…',
#  'Families',
#  'across',
#  'country',
#  'affected',
#  'substance',
#  'abuse,',
#  "Trump's",
#  'no',
#  'different.',
#  '\n\n"[My',
#  'brother',
#  'Fred]',
#  'h…',
#  '#StopTheBias',
#  'https://t.co/xqz599iQZw',
#  'New',
#  'report',
#  '@CommerceGov:',
#  'growth',
#  'original',
#  'estimates',
#  'April',
#  'June',
#  '2018—the',
#  'qua…',
#  '“We',
#  'political',
#  'monoculture',
#  'that’s',
#  'intolerant',
#  'views,”',
#  'senior',
#  'Facebook',
#  'engineer',
#  'wrote',
#  'post',
#  '"qui…',
#  'White',
#  'House',
#  'Counsel',
#  'Don',
#  'McGahn',
#  'leaving',
#  'his',
#  'position',
#  'fall,',
#  'shortly',
#  'after',
#  'confirmation',
#  '(hopefully)',
#  'of…',
#  'Add',
#  'World',
#  'Cup',
#  'long',
#  'list',
#  'accomplishments!',
#  '@realDonaldTrump',
#  'excited',
#  'United',
#  'States,',
#  'along',
#  'Canada,',
#  '@FIFAW…',
#  'https://t.co/H2FiSVxyOF',
#  '.@RepKevinBrady',
#  'praises',
#  'U.S.–Mexico',
#  'Trade',
#  'Agreement',
#  'its',
#  '"American',
#  'workers,',
#  'farmers,',
#  'local',
#  'busin…',
#  '.@RepArrington:',
#  '"[I]',
#  'am',
#  'confident',
#  'Negotiator-in-Chief',
#  'close',
#  'Americans."',
#  'https://t.co/CYIw…',
#  '“Consumer',
#  'confidence',
#  'pops',
#  'August',
#  'highest',
#  'level',
#  'October',
#  '2000”',
#  'https://t.co/1Gg5IOtbNa',
#  '.@SteveScalise:',
#  "America's",
#  'preliminary',
#  '"will',
#  'send',
#  'message',
#  'other',
#  'countries',
#  'around',
#  'world…',
#  '@VP:',
#  'Honored',
#  'join',
#  '@POTUS',
#  '@FLOTUS',
#  'tonight',
#  'celebrate',
#  'inspiring',
#  'evangelical',
#  'leadership.',
#  'This',
#  'administ…',
#  'wonderful',
#  'host',
#  'Evangelical',
#  'leaders',
#  'tonight.',
#  'https://t.co/8R4jC6VVJr',
#  '“Many',
#  'people',
#  'thought',
#  'this',
#  'something',
#  'couldn’t',
#  'happen',
#  'because',
#  'factions,',
#  'the…',
#  'had',
#  'honor',
#  'contribute',
#  'beautiful',
#  'historic',
#  'grounds',
#  'today',
#  'planting',
#  'sapling',
#  'Eisenhower',
#  'O…',
#  '.@POTUS',
#  'welcomed',
#  '@UKenyatta',
#  'Mrs.',
#  'Kenyatta',
#  'today.',
#  'enjoyed',
#  'my',
#  'time',
#  'First',
#  'Lady',
#  'Kenya,',
#  'discu…']

# %%
# reformat most common 10 items into dictionary
    # dictionary comprehension
        # k:d[k] (return the value of k, mapped to the value of k within the d dictionary)
        # for k (iterating through each value of k)
        # in srted[:10] (for the first 10 values of srted)
        #{} (return in a dictionary)
srted_dict = {k:d[k] for k in srted[:10]}
srted_dict
# Out:
# {'RT': 21,
#  'the': 19,
#  'to': 12,
#  '@WhiteHouse:': 10,
#  'a': 7,
#  'in': 6,
#  'and': 6,
#  '@realDonaldTrump:': 6,
#  'that': 6,
#  'of': 6}
